# %% [markdown]
# <a href="https://colab.research.google.com/github/ansarshaikh99/EDA-Hotel-booking-analysis/blob/main/EDA_Hotel_booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - EDA - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Ansar Shaikh (Individual)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The hotel bookings dataset is a large dataset containing information about hotel bookings made by customers. The dataset contains 119,390 observations and 32 variables, including information about the customer, the hotel, the booking, and the stay.
#
# The project aims to explore the dataset and answer some questions related to the booking patterns of customers, such as:
#
# 1. What is the distribution of bookings by hotel type (city or resort)?
# 2. What are the most popular months for bookings?
# 3. What is the average lead time for bookings?
# 4. What is the cancellation rate for bookings?
# 5. What are the main factors that influence cancellations?
#
# To answer these questions, we first loaded the dataset into a Pandas dataframe using the read_csv() method. We then cleaned the data by removing missing values, duplicates, and irrelevant columns. We also converted some of the categorical variables into numerical variables to facilitate analysis.
#
# <br>We then performed exploratory data analysis (EDA) to gain insights into the data. We used various visualization techniques, such as histograms, box plots, scatter plots, and heatmaps, to visualize the distributions, relationships, and correlations between the variables. We also used statistical methods, such as descriptive statistics, hypothesis testing, and regression analysis, to quantify the patterns and relationships in the data.<br>
#
# Our analysis revealed several interesting findings:
#
# 1. The majority of bookings are made for city hotels (66.4%) rather than resort hotels (33.6%).
#
# 2. The most popular months for bookings are August, July, and May, while the least popular months are November, December, and January.
#
# 3. The average lead time for bookings is around 104 days, but it varies significantly between hotels, countries, and market segments.
#
# 4. The cancellation rate for bookings is around 37%, but it also varies significantly depending on the hotel type, booking channel, and customer type.
#
# 5.  main factors that influence cancellations are the lead time, the type of customer, the type of room, the arrival date, and the number of special requests.
#
#
# Based on these findings, we provided some recommendations for hotel managers to optimize their bookings and reduce cancellations, such as:
#
# 1. To focus on attracting more customers to resort hotels during the low season (November to January) by offering special promotions and packages.
#
# 2. To adjust their pricing and revenue management strategies based on the demand patterns of different market segments and customer types.
#
# 3. To use predictive analytics and machine learning models to forecast cancellations and overbooking risks and optimize their inventory and pricing strategies accordingly.
#
#
# Overall, the hotel bookings dataset project demonstrates the importance of data analysis and visualization in understanding customer behavior and optimizing business operations. The project also highlights the challenges of dealing with large and complex datasets and the need for data cleaning, preprocessing, and visualization techniques to extract meaningful insights.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/ansarshaikh99/EDA-Hotel-booking-analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of
# stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely
# to receive a disproportionately high number of special requests? This hotel booking dataset can help
# you explore those questions!**
#
#
# **This data set contains booking information for a city hotel and a resort
# hotel, and includes information such as when the booking was made, length of stay, the number of
# adults, children, and/or babies, and the number of available parking spaces, among other things. All
# personally identifying information has been removed from the data. Explore and analyse the data to
# discover important factors that govern the bookings.**
#
#
#
# ![hotel.png](data:image/png;base64,...)

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective for analyzing this hotel booking dataset could be to identify patterns and factors that impact bookings for city and resort hotels.
# This analysis could help hotel managers optimize their pricing and marketing strategies, improve their services and amenities, and better understand their customers needs and preferences.
#
# Additionally, this analysis could help predict future demand for hotel bookings, enabling hotel managers to plan and allocate their resources effectively. Overall, the objective is to leverage the data to gain insights and make data-driven decisions that improve the hotel's profitability and customer satisfaction.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
path = "/content/drive/MyDrive/Colab Notebooks/Almabetter/Python/Module - I/Cap Stone project 1/EDA project/Data/Hotel Bookings.csv"
df = pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Gives first 5 rows
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Gives latst 5 rows
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
count_row = df.shape[0]  # Gives number of rows
count_col = df.shape[1]  # Gives number of columns
print(f'Total number of rows in dataset is : {count_row}') 
print(f'Total number of columns in dataset is : {count_col}')
# Out:
# Total number of rows in dataset is : 119390
# Total number of columns in dataset is : 32

# %%
# Also we can used this method to to get the number of rows and columns
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_values = df.apply(lambda x : sum(x.value_counts() > 1)) 
print(f"Duplicate value count data is given below \n {duplicate_values}")
# Out:
# Duplicate value count data is given below
#  hotel                                2
# is_canceled                          2
# lead_time                          467
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             15
# stays_in_week_nights                27
# adults                               9
# children                             4
# babies                               3
# meal                                 5
# country                            147
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              14
# previous_bookings_not_canceled      36
# reserved_room_type                  10
# assigned_room_type                  11
# booking_changes                     18
# deposit_type                         3
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_counts = df.isna().sum().sort_values(ascending=False)
print("Number of missing value in each columns: \n" , null_counts)
# Out:
# Number of missing value in each columns:
#  company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# ...

# %%
# Visualizing the missing values
# Setting figure size
plt.figure(figsize=(8,5))

#Plotting heatmap for which shows the null or missing value in dataset
sns.heatmap(df.isna(), cbar=False)

#Display the plot
plt.show()

# %%
#Replacing NULL values in company and agent columns with 0
values = {'company': 0, 'agent': 0}

df.fillna(value = values, inplace = True)

#Replacing NULL values in country column with most frecuent value
df['country'].fillna(value = df['country'].mode()[0], inplace = True)

#Removing row affected by NULL values in children column
df.dropna(subset = ['children'], inplace = True)

# %%
#Rechecking for NULL values in the data set
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# Replacing 'Undefined' values in the 'meal' column with 'SC'
df['meal'].replace('Undefined', 'SC', inplace=True)

#Rechecking unique values in meal column
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC'], dtype=object)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# A dataset is a collection of data that has been organized in a structured way, usually in a table or spreadsheet format. It typically contains information about a specific topic or domain, such as sales figures, customer demographics, or medical records.
#
# <br>Datasets can come in many different sizes and formats, ranging from small and simple to large and complex. They can be created and used for various purposes, such as research, analysis, machine learning, and predictive modeling.<br>
#
# <br>One important aspect of datasets is their quality, which refers to the accuracy, completeness, and consistency of the data. Good quality data is essential for producing reliable and useful insights and results.<br>
#
# <br>Overall, datasets are a fundamental building block of data-driven approaches and play a critical role in many fields, including business, science, healthcare, and government.<br>

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119386.000000  119386.000000      119386.000000
# mean        0.370395     104.014801        2016.156593
# std         0.482913     106.863286           0.707456
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119386.000000              119386.000000
# mean                  27.165003                  15.798553
# std                   13.605334                   8.780783
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# A variable is a characteristic or property that can take on different values, and it is used to represent information in a dataset. In other words, a variable is a feature that can vary from one observation to another.
#
# <br>For example, in a dataset about student performance, variables might include the student's age, gender, grade level, test scores, and attendance record. Each of these variables can take on different values for each student in the dataset.<br>
#
# <br>Variables can be classified into different types, depending on their nature and the type of data they represent. For example, categorical variables represent data that can be divided into discrete categories or groups, such as gender, ethnicity, or product type. Numerical variables, on the other hand, represent data that can take on numerical values, such as height, weight, or temperature.<br>
#
# <br>Understanding variables is important because they are the building blocks of data analysis and statistics. By examining and analyzing the variables in a dataset, we can gain insights into the patterns and relationships that exist within the data, and use that information to make informed decisions and predictions.<br>

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = {}   # taking a empty dictionary to store the unique values for each variable. 

for column in df.columns:
    unique_values[column] = df[column].unique()

for column, unique_values in unique_values.items():          
    print(f"Unique values for {column} is: {unique_values}")      # This will print the unique values for each variable
    

# unique_values = {column: df[column].unique() for column in df}
# unique_values
# Out:
# Unique values for hotel is: ['Resort Hotel' 'City Hotel']
# Unique values for is_canceled is: [0 1]
# Unique values for lead_time is: [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
numerical_columns = []
for column in df.columns:
  if df[column].nunique()>5:
    numerical_columns.append(column)
categorical_columns = list(set(df.columns) - set(numerical_columns))

# %%
print(numerical_columns)
# Out:
# ['lead_time', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'country', 'market_segment', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr', 'total_of_special_requests', 'reservation_status_date']

# %%
print(categorical_columns)
# Out:
# ['distribution_channel', 'required_car_parking_spaces', 'children', 'hotel', 'babies', 'arrival_date_year', 'customer_type', 'meal', 'deposit_type', 'is_repeated_guest', 'is_canceled', 'reservation_status']

# %%
# Check the data types of the columns
print("Data types of columns:\n", df.dtypes)
# Out:
# Data types of columns:
#  hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I have just performed some basic data exploration on the Hotel Bookings dataset to get a sense of its structure and the quality of its data. Here are the key insights I found:
#
#
#
# 1.   The dataset contains 119,390 rows and 32 columns.
#
# 2.   There are missing values in the 'children', 'country', 'agent', and 'company' columns. The 'company' column has a large number of missing values (93.3% of the values in that column are missing).
#
# 3.   The 'children', 'agent', and 'company' columns have floating-point data types, which might not be appropriate for these variables.
#
# 4.   The 'arrival_date_month' column has the names of the months as strings, which might make it harder to perform date-based analysis on this dataset.
#
# 5.   The 'reservation_status' column might not be useful for predicting cancellations since it reveals the outcome of the reservation (e.g., "Canceled", "No-Show", or "Check-Out") and might not be known at the time of booking.
#
#
# Based on these observations, we could perform some data cleaning and preprocessing steps to address these issues, such as:
#
#
# 1.   Filling in missing values (e.g., by imputation, using the most common value, or dropping rows with missing values).
# 2.   Converting the 'children', 'agent', and 'company' columns to integer data types, if appropriate.
#
# 3.   Converting the 'arrival_date_month' column to a datetime data type, which will enable us to extract the month of arrival and perform date-based analysis.
#
# 4.   Removing the 'reservation_status' column, as it might not be useful for our predictive models.
#
#
# Further, we could perform more detailed exploratory data analysis (EDA) to gain more insights about the data, such as:
#
# 1.   Understanding the distributions and correlations of the numerical variables in the dataset (e.g., 'lead_time', 'adr', etc.).
#
# 2.   Investigating the relationships between the target variable ('is_canceled') and other variables in the dataset (e.g., 'arrival_date_month', 'market_segment', etc.).
#
# 3.   Identifying patterns and trends in the data over time (e.g., changes in cancellation rates over different years or months).
#
# 4.   Performing feature engineering to create new variables that might be useful for predicting cancellations (e.g., total number of guests, total number of nights stayed, etc.).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 - Which type of hotel booked most and we will plot bar chart and pie chart for hotels for better understanding

# %%
#getting unique value of hotel
Unique_hotel = df['hotel'].unique()
print(f'The unique values for hotel is {Unique_hotel}')
# Out:
# The unique values for hotel is ['Resort Hotel' 'City Hotel']

# %%
#Checking which hotel type have most booking 
most_booking_count = df['hotel'].value_counts(ascending=False)
most_booking_count
# Out:
# City Hotel      79326
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
print(f"Most booking hotel is: {most_booking_count.index[0]}")
# Out:
# Most booking hotel is: City Hotel

# %%
# Setting the figure size
plt.figure(figsize=(8,6))

# Creating a bar chart
sns.countplot(x="hotel",data=df,hue="hotel",palette="Oranges",edgecolor="black")

# Adding a title
plt.title('Hotel Bookings', fontsize=13)

# Setting the x-axis label
plt.xlabel('Hotel', fontsize=14)

# Setting the y-axis label
plt.ylabel('Number of Bookings', fontsize=14)

# Displaying the plot
plt.show()

# %%
# Counting the number of bookings for each hotel
booking_counts = df['hotel'].value_counts()

# Setting the figure size
plt.rcParams['figure.figsize'] = 8,8

# Determining colour of pie chart 
colors = ['orange', 'red']

# Creating a pie chart
plt.pie(booking_counts, labels=booking_counts.index, autopct='%.0f%%',startangle=90, explode=[0,0.04], textprops={'fontsize': 15},colors=colors)

# Adding a title
plt.title('Percentage Bookings of Hotel', fontsize=16)

# Displaying the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose the pie chart because it will provide a clear visual representation of the percentage of bookings for each hotel type, and it is easy to understand at a glance.
#
#
# I also choose the bar chart because it is useful for comparing the number of bookings for each hotel type, and it can highlight any significant differences between them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the charts, the insight obtained is that the majority of the bookings made were for City Hotels. City hotels account for 66 % of all bookings, followed by Resort Hotels, which account for 34 % of all bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
#
#
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the chart can help create a positive business impact by providing valuable information for the hotel industry. For example, hotel chains can use this information to optimize their marketing strategies, adjust their pricing based on demand, and make informed decisions about expanding or investing in different types of hotels.
#
# <br>No, there are no insights that lead to negative growth. The data provided shows that all hotel types received bookings, and there is no indication that any type of hotel is performing poorly or experiencing negative growth.<br>

# %% [markdown]
# #### Chart - 2 - Which Hotel has More Cancelled Booking?

# %%
# Checking total cancel value count this gives overall booking and cancel values 
df['is_canceled'].value_counts()
# Out:
# 0    75166
# 1    44220
# Name: is_canceled, dtype: int64

# %%
# Checking booking and cancel count indivisually
df.groupby(["hotel","is_canceled"]).size()
# Out:
# hotel         is_canceled
# City Hotel    0              46228
#               1              33098
# Resort Hotel  0              28938
#               1              11122
# dtype: int64

# %%
# Grouping the data by hotel and is_canceled columns and count the values
cancel_count = df.groupby(["hotel","is_canceled"]).size().reset_index(name="count")

# Select only the rows where is_canceled == 1 (canceled bookings)
cancel_count = cancel_count[cancel_count['is_canceled']==1]

#printing result
cancel_count
# Out:
#           hotel  is_canceled  count
# 1    City Hotel            1  33098
# 3  Resort Hotel            1  11122

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8,6))

# Creating the count plot using Seaborn
sns.countplot(x="hotel", data=df, hue="is_canceled", palette="Blues", edgecolor="black")

# Adding legend with "Booking" and "Canceled"
plt.legend(title='Booking Vs Canceled', labels=['Booking', 'Canceled'])

# Adding a title
plt.title('Hotel Bookings vs canceled', fontsize=13)

# Setting the x-axis label
plt.xlabel('Hotel', fontsize=14)

# Setting the y-axis label
plt.ylabel('Number of Bookings vs canceled', fontsize=14)

# Displaying the plot
plt.show()

# %%
# Checking cancellation percentage
cancel_percentage = df.groupby('hotel')['is_canceled'].mean() * 100

# Print the results
print(f'Percentage of cancellation is: {cancel_percentage}')
# Out:
# Percentage of cancellation is: hotel
# City Hotel      41.724025
# Resort Hotel    27.763355
# Name: is_canceled, dtype: float64

# %%
# Grouping the data by hotel and is_canceled columns and count the values
cancel_count = df.groupby(["hotel","is_canceled"]).size().reset_index(name="count")

# Select only the rows where is_canceled == 1 (canceled bookings)
cancel_count = cancel_count[cancel_count['is_canceled']==1]

# Determining colour of pie chart 
colors = ['red', 'orange']

# Creating a pie chart
plt.pie(cancel_count['count'], labels=cancel_count['hotel'], autopct="%.0f%%", startangle=90, textprops={'fontsize':15}, explode=[0,0.04],colors=colors)

# Displaying the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose this chart because it shows the number of bookings and cancelled bookings for each hotel, with different colors representing the two categories. The x-axis shows the hotel name, and the y-axis shows the number of bookings/cancelled bookings.
#
# <br>The advantage of this chart is that it provides a visual representation of both the number of bookings and cancelled bookings for each hotel, making it easy to compare and see the difference. Additionally, the hue parameter of the countplot allows us to see the number of cancelled bookings for each hotel as a separate bar beside the total bookings bar.<br>
#
# <br>The legend also makes it easy to interpret the chart, as it clearly shows the difference between bookings and cancelled bookings.<br>

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights gained from the chart would be which hotel has the most cancelled bookings. By looking at the horizontal bar chart, we can quickly see the ranking of hotels from the one with the highest number of cancelled bookings to the one with the lowest number of cancelled bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the chart can help create a positive business impact by providing valuable information for hotel managers to identify patterns and reasons for the high number of cancelled bookings. The hotel can use this information to take appropriate actions to reduce cancellations, such as improving customer service or offering more flexible cancellation policies.
#
# <br>Yes, there may be insights that lead to negative growth. For example, if a particular hotel consistently has a high number of cancelled bookings, it could indicate that there are issues with the hotel's service, facilities, or location. This could result in negative feedback and lower occupancy rates, leading to a negative impact on the hotel's business growth. Therefore, it is important for hotel managers to address the issue of cancelled bookings promptly and take necessary actions to improve customer satisfaction.<br>

# %% [markdown]
# #### Chart - 3 - Hotel Booking Trend Over the Year and Month

# %%
# Hotel Booking Trend checking for year 
year=df.groupby(["arrival_date_year"])[["arrival_date_year"]].count()
year
# Out:
#                    arrival_date_year
# arrival_date_year
# 2015                           21992
# 2016                           56707
# 2017                           40687

# %%
# Chart - 3 visualization code
#setting figure size
plt.rcParams['figure.figsize'] = 12, 8

#Ploting countplot for year wise booking
sns.countplot(x= df["arrival_date_year"], data=df, hue="hotel", palette="inferno_r", edgecolor="black")

# Adding title
plt.title("Year wise Hotel Booking")

#Setting the x-axis label
plt.xlabel('Year')

#Setting the y-axis label
plt.ylabel('Booking')

#display the plot
plt.show()

# %%
# Hotel Booking Trend checking for month
month = df.groupby(["arrival_date_month"])[["hotel"]].count()
month
# Out:
#                     hotel
# arrival_date_month
# April               11089
# August              13873
# December             6780
# February             8068
# January              5929
# July                12661
# June                10939
# March                9794
# May                 11791
# November             6794
# October             11160
# September           10508

# %%
#setting figure size
plt.rcParams['figure.figsize'] = 15,10

#plotting countplot for month wise booking
sns.countplot(x= df["arrival_date_month"], data=df , order=month.index,hue="hotel", palette="gray", edgecolor="black")

# Adding title
plt.title("Month wise Hotel Booking")

#Setting the x-axis label
plt.xlabel('Month')

#Setting the y-axis label
plt.ylabel('Booking')

#Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the countplot chart because it is useful for visualizing the frequency or count of categorical data. In this case, we want to see the trend of hotel bookings over the months and years.
#
# <br>From the first chart, we can see that hotel bookings are generally higher during the summer months of June, July, and August. We can also see that city hotels have more bookings compared to resort hotels, except for the month of August. From the second chart, we can see that the number of hotel bookings has been increasing each year, with the highest number of bookings in 2016.<br>

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the Month wise Hotel Booking chart, we can observe that the summer months of June, July, and August have the highest number of bookings for both types of hotels. Additionally, we can see that City hotels have a higher number of bookings compared to Resort hotels in most months.
#
# <br>From the Year wise Hotel Booking chart, we can see that the number of bookings has been increasing each year from 2015 to 2016 and then from 2016 to 2017. Moreover, we can see that City hotels have consistently higher bookings compared to Resort hotels in all years. This indicates that the business of City hotels is performing better than Resort hotels.<br>

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. Hotel managers can use this information to adjust their staffing levels, room rates, and inventory based on the expected demand for each month and year. By optimizing their operations, they can increase revenue and profitability.
#
#
# <br>There are no specific insights that would lead to negative growth, but it is important to note that hotel bookings are subject to various external factors such as the economy, weather, and global events. Hotel managers should always be prepared for unexpected changes in demand and adjust their strategies accordingly.<br>

# %% [markdown]
# #### Chart - 4 - Which Country Has Most No. of Hotels ?

# %%
# Chart - 4 visualization code
#Creating dataframe for country and number of booking
country_counts = df["country"].value_counts()[:15].reset_index().rename(columns={"index":'Country',"country":"No.of bookings"})
country_counts
# Out:
#    Country  No.of bookings
# 0      PRT           49074
# 1      GBR           12129
# 2      FRA           10415
# 3      ESP            8568
# 4      DEU            7287
# 5      ITA            3766
# 6      IRL            3375
# 7      BEL            2342
# 8      BRA            2224
# 9      NLD            2104
# 10     USA            2097
# 11     CHE            1730
# 12      CN            1279
# 13     AUT            1263
# 14     SWE            1024

# %%
#Creating a barplot for top 10 countries

#setting figure size
plt.figure(figsize=(12,8))

#Ploting barplot for top 10 countries
sns.barplot(x=country_counts['Country'], y=country_counts['No.of bookings'], 
            data=country_counts, palette="muted", edgecolor="black")   

#display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was picked which is a bar plot with the x-axis showing the top countries with the highest number of hotel bookings and the y-axis showing the frequency of hotel bookings in each country. The hue parameter is used to distinguish between two types of hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be found from the chart are:
#
# The top three countries with the highest number of hotel bookings are Portugal, the United Kingdom, and Spain.
# Both resort and city hotels are more popular in Portugal, the United Kingdom, and Spain.
# City hotels are more popular than resort hotels in all countries except for Portugal and Spain, where both types of hotels are equally popular.
# The gained insights can help create a positive business impact by providing information on which countries have the highest demand for hotel bookings and which type of hotel is more popular in each country. This can help hotel managers and marketers tailor their marketing and promotional strategies to target customers in these countries and offer services that meet their preferences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are no insights from the chart that lead to negative growth. The chart provides information on the current state of hotel bookings in different countries and types of hotels, and it does not indicate any negative trends or factors that could lead to a decrease in demand for hotel bookings.

# %% [markdown]
# #### Chart - 5 - Month and hotel wise ADR

# %%
# Group the data by hotel and arrival month and calculate the mean ADR
adr_by_month_and_hotel = df.groupby(['hotel', 'arrival_date_month'])['adr'].mean().reset_index()

# Print the result
print(adr_by_month_and_hotel)
# Out:
#            hotel arrival_date_month         adr
# 0     City Hotel              April  111.251838
# 1     City Hotel             August  114.718346
# 2     City Hotel           December   88.826307
# 3     City Hotel           February   85.088278
# 4     City Hotel            January   82.628986
# 5     City Hotel               July  110.734292
# 6     City Hotel               June  119.074341
# 7     City Hotel              March   92.643116
# 8     City Hotel                May  121.638560
# 9     City Hotel           November   88.069601
# 10    City Hotel            October   99.974498
# 11    City Hotel          September  110.004661
# 12  Resort Hotel              April   77.849496
# 13  Resort Hotel             August  186.790574
# 14  Resort Hotel           December   68.984230
# 15  Resort Hotel           February   55.171930
# 16  Resort Hotel            January   49.461883
# 17  Resort Hotel               July  155.181299
# 18  Resort Hotel               June  110.444749
# ...

# %%
# Chart - 5 visualization code
plt.figure(figsize=(15,6))

#Plotting lineplot for ADR acording to month
sns.lineplot(x='arrival_date_month', y='adr', hue='hotel', data= df,
             palette='crest')

# Adding title
plt.title("Month & Hotel wise Average Daily Rate ")

#Setting the x-axis label
plt.xlabel('Month')

#Setting the y-axis label
plt.ylabel('Rate')

#Display the plot
plt.show()

# %%
#checking hotel wise daily rates mean, standard deviation, meadian, min and max
df.groupby(["hotel"]).adr.agg(["mean","std","min","median","max"])
# Out:
#                     mean        std   min  median     max
# hotel
# City Hotel    105.308282  43.600314  0.00    99.9  5400.0
# Resort Hotel   94.952930  61.442418 -6.38    75.0   508.0

# %%
#checking hotel and month wise daily rates mean, standard deviation, meadian,
# min and max
df.groupby(["hotel","arrival_date_month"]).adr.agg(["mean","std","min",
                                                        "median","max"])
# Out:
#                                        mean        std   min   median      max
# hotel        arrival_date_month
# City Hotel   April               111.251838  36.128762  0.00  105.000   336.00
#              August              114.718346  45.945593  0.00  109.000   372.33
#              December             88.826307  35.022401  0.00   85.000   451.50
#              February             85.088278  28.781711  0.00   80.000   284.20
#              January              82.628986  25.350968  0.00   80.000   284.20
#              July                110.734292  41.898966  0.00  107.100   365.00
#              June                119.074341  36.084648  0.00  117.370   333.67
#              March                92.643116  72.889867  0.00   88.000  5400.00
#              May                 121.638560  39.966153  0.00  120.000   510.00
#              November             88.069601  30.717129  0.00   85.000   260.00
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the line chart because it is suitable for showing trends and changes over time. In this case, we want to see how the average daily rate (ADR) of hotels changes over the months.
#
# From the chart, we can see that the ADR for both city and resort hotels are highest in the summer months of June, July, and August. This is likely because these months are peak tourist season in many regions. We can also see that ADR is generally higher for city hotels compared to resort hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Yes, the gained insights can help create a positive business impact. Hotel managers can use this information to adjust their pricing strategies based on the season and the type of hotel they are managing. By optimizing their pricing, they can increase revenue and profitability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# One insight that could lead to negative growth is the fact that ADR is generally higher for city hotels compared to resort hotels. This could mean that resort hotels may need to offer more competitive pricing to attract customers, which could lead to lower profitability. However, this would depend on the specific market and demand in each location, so it is not necessarily a negative insight in all cases.

# %% [markdown]
# #### Chart - 6 - Month with the most guest arrivals

# %%
# Group the data by hotel and arrival month and sum the adults and children columns
monthly_guests = df.groupby(['hotel', 'arrival_date_month'])[['adults', 'children']].sum()

# Add a column for the total number of guests
monthly_guests['total_guests'] = monthly_guests['adults'] + monthly_guests['children']

# Reset the index to make hotel and month columns into regular columns
monthly_guests = monthly_guests.reset_index()

# Pivot the data to make the months into columns and the hotels into rows
monthly_guests_pivot = monthly_guests.pivot(index='arrival_date_month', columns='hotel', values='total_guests')

# Reorder the months from January to December
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
monthly_guests_pivot = monthly_guests_pivot.reindex(month_order)

# Print out the month with the highest number of guests for each hotel
print(monthly_guests_pivot.idxmax())
# Out:
# hotel
# City Hotel      August
# Resort Hotel    August
# dtype: object

# %%
# Chart - 6 visualization code

# Setting figure size
plt.figure(figsize = (13, 7))

# Setting up month order
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

#Plotting countplot for most guest arrrival in month
sns.countplot(x='arrival_date_month', hue='hotel', data=df, order=month_order, palette = 'PuBuGn')

# Adding title
plt.title("Guest arrival in month")

#Setting the x-axis label
plt.xlabel('Months')

#Setting the y-axis label
plt.ylabel('Number of bookings')

#Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have choose this chart because it is a suitable way to visualize the frequency of categorical data in a dataset, in this case, the number of hotel bookings in each month. The countplot is also effective in comparing the frequency of two or more categorical variables, which allows us to see the differences in the number of bookings between the two hotel types in each month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can see the number of hotel bookings in each month of the year, broken down by hotel type (City hotel or Resort hotel). The busiest month for both hotels is August, while the least busy month is January. Additionally, the City hotel appears to have a higher number of bookings overall compared to the Resort hotel, with July and August being the busiest months for the City hotel and June and July being the busiest months for the Resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact as it can aid in forecasting demand for hotel bookings in each month and guide the hotels in managing their inventory and pricing strategies accordingly. This information can also be used to optimize staffing levels and allocate resources during peak and off-peak seasons.
#
#
#
# <br>One potential insight that could lead to negative growth is the fact that January is the least busy month for both hotels. This could indicate a potential low season for tourism in the area and may require hotels to adjust their pricing strategies and marketing efforts to attract more bookings during this period. However, this insight can also be seen as an opportunity for hotels to offer discounts or promotions to attract more guests during the low season and boost their occupancy rates.<br>

# %% [markdown]
# #### Chart - 7 - Day Wise Trend of Visitor In Hotels

# %%
# Chart - 7 visualization code

# Setting figure size
plt.figure(figsize=(15,6))

#Plotting countplot for visitor in hotel in a day
sns.countplot(data = df, x = 'arrival_date_day_of_month', hue='hotel', palette='Paired')

# Adding title
plt.title("Day wise visitor")

#Setting the x-axis label
plt.xlabel("Days")

#Setting the y-axis label
plt.ylabel("Number of visitors")

#Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have choose this chart because it is a suitable way to visualize the frequency of categorical data in a dataset, in this case, the number of visitors to the hotel in each day of the month. The countplot is also effective in comparing the frequency of two or more categorical variables, which allows us to see the differences in the number of visitors between the two hotel types on each day of the month. This can provide insights into the demand patterns of hotel visitors, which can help hotels in managing their inventory, pricing strategies, and resource allocation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can see the number of visitors to the hotel in each day of the month, broken down by hotel type (City hotel or Resort hotel). The chart shows that the number of visitors is relatively consistent throughout the month, with a slight dip in the middle of the month. Additionally, the City hotel appears to have a higher number of visitors overall compared to the Resort hotel, with a more consistent pattern of daily visitors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact as it can aid in forecasting demand for hotel bookings on a day-to-day basis, which can help hotels in managing their inventory, pricing strategies, and resource allocation accordingly. This information can also be used to optimize staffing levels and provide better customer service during peak and off-peak days.
#
# <br>There are no specific insights that lead to negative growth in this chart. However, it is worth noting that the chart only shows the number of visitors to the hotel and does not provide any information on their satisfaction level or the revenue generated by their visits. Therefore, it is important to analyze other metrics to fully understand the impact of these insights on business growth.<br>

# %% [markdown]
# #### Chart - 8 - How many reservations were made by repeated guests?

# %%
# Count the number of reservations made by customers who have previously cancelled a booking or made a previous booking that was not canceled
repeat_customers = len(df[(df['previous_cancellations'] > 0) | (df['previous_bookings_not_canceled'] > 0)])

# Count the number of reservations made by new customers
new_customers = len(df) - repeat_customers

# Print the result
print(f"{repeat_customers} reservations were made by repeated guests.")
# Out:
# 9457 reservations were made by repeated guests.

# %%
# Chart - 8 visualization code

# Setting figure size
plt.figure(figsize = (10, 5))

counts = [repeat_customers, new_customers]

# Create a list of labels for the pie chart
labels = ['Repeated Customers', 'New Customers']

# Determining colour of pie chart 
colors = ['green', 'orange']

# Creating the pie chart
plt.pie(counts, labels=labels, autopct='%1.1f%%',colors=colors )

# Adding a title
plt.title('Percentage of Booking by Customer Type')

# Dispaly the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart is chosen by me is a pie chart, which is often used to display data as a proportion of a whole. In this case, the chart is used to show the proportion of hotel bookings made by repeated customers and new customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the majority of hotel bookings are made by new customers, with 92.1% of bookings made by new customers and 7.1% of bookings made by repeated customers. This indicates that the hotel may need to focus on acquiring new customers to increase revenue, while also maintaining the loyalty of existing customers. It is also important to note that the chart only considers whether a customer has previously cancelled a booking or made a previous booking that was not canceled, and does not provide information on other factors that may influence customer loyalty.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can help create a positive business impact as it can aid in identifying the customer base and developing strategies to attract and retain customers. For example, the hotel can focus on offering personalized experiences, loyalty programs, and other incentives to encourage repeat bookings from existing customers while also investing in marketing and advertising campaigns to attract new customers.
#
#
# <br>There are no specific insights that lead to negative growth in this chart. However, it is important to note that the pie chart only considers a single factor, whether a customer has previously cancelled a booking or made a previous booking that was not canceled, and does not provide information on other factors that may impact customer loyalty, such as pricing, quality of service, and amenities. Therefore, it is important to analyze other metrics and factors to fully understand the impact of customer loyalty on business growth.<br>

# %% [markdown]
# #### Chart - 9 - What is the number of stays on weekend night vs cancel and week day vs cancel?

# %% [markdown]
# Number of stays on weekend night vs cancel?

# %%
# Chart - 9 visualization 
# Setting figure size
plt.figure(figsize=(15, 8))

# Creating supbplot
plt.subplot(1, 2, 1)

# Plotting countplot for stay in weekend
sns.countplot(x='stays_in_weekend_nights',hue='hotel', data=df, palette='flare')

# Adding title
plt.title("Number of stays on weekend nights",fontweight="bold", size=20)

# Setting up legend
plt.legend(loc='upper right')

# Adding title
plt.title("Number of stays on weekend night",fontweight="bold", size=20)

#Setting the x-axis label
plt.xlabel("Stays weekend night")

#Setting the y-axis label
plt.ylabel("count")

# Creating supbplot
plt.subplot(1, 2, 2)

# Plotting countplot for stay in weekend vc cancellation
sns.countplot(data = df, x = 'stays_in_weekend_nights', hue='is_canceled', palette='viridis')

# Adding title
plt.title('stays in weekend nights vs cancelation',fontsize=20)

# Adjusting subplot
plt.subplots_adjust(right=1.5)

# Setting up legend
plt.legend(labels=['Booking', 'Canceled'],loc='upper right')

# Adding title
plt.title("Number of stays on weekend night vs cancelation")

#Setting the x-axis label
plt.xlabel("Stays weekend night")

#Setting the y-axis label
plt.ylabel("count")

#Display the plot
plt.show()

# %% [markdown]
# Number of stays on week day vs cancel?

# %%
# Setting figure size
plt.figure(figsize=(15, 8))

# Creating supbplot
plt.subplot(1, 2, 1)

# Plotting countplot for stay in weekend
sns.countplot(x='stays_in_week_nights',hue='hotel', data=df, palette='rainbow_r')

# Setting up legend
plt.legend(loc='upper right')

# Adding title
plt.title("Number of stays on weekday nights",fontweight="bold", size=20)

#Setting the x-axis label
plt.xlabel("Stays in week night")

#Setting the y-axis label
plt.ylabel("count")

# Creating supbplot
plt.subplot(1, 2, 2)

# Plotting countplot for stay in weekend
sns.countplot(data = df, x = 'stays_in_week_nights', hue='is_canceled', palette='magma_r')

# Setting up legend
plt.legend(labels=['Stay', 'Canceled'],loc='upper right')

# Adding title
plt.title('Weekday vs Cancelations',fontweight="bold", size=20)

#Setting the x-axis label
plt.xlabel("Stays in week night")

#Setting the y-axis label
plt.ylabel("count")

# Adjusting subplot
plt.subplots_adjust(right=1.7)

#Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason for picking these specific charts is to visualize the distribution of stays on weekend nights and weekday nights, and their correlation with cancellations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the first chart, it is evident that most of the bookings made were for 1 or 2 stays on weekend nights, and City Hotel has more bookings as compared to Resort Hotel.
#
# <br>From the second chart, it is clear that the majority of stays on weekday nights were for 1 to 4 nights, and most bookings were not canceled.<br>

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights can help in creating a positive business impact by understanding customer behavior and preferences for stays on weekend nights and weekday nights. The hotel management can offer specific discounts or packages to attract customers for longer stays or bookings on weekdays.
#
# <br>There are no insights that lead to negative growth. However, it is important to note that cancellations can have a negative impact on revenue, and the hotel management should try to minimize cancellations by providing better services and facilities to customers.<br>

# %% [markdown]
# #### Chart - 10 - Which Customer Type Demanded Most No. Special requests?

# %%
# Group the data by customer type and total special requests
special_request = df.groupby("customer_type")["total_of_special_requests"].sum().to_frame()
special_request
# Out:
#                  total_of_special_requests
# customer_type
# Contract                              2971
# Group                                  372
# Transient                            56598
# Transient-Party                       8269

# %%
# Chart - 10 visualization code

# Setting figure size
plt.figure(figsize=(20,10))

# Creating a pie chart to check the percentage of request
plt.pie(special_request["total_of_special_requests"], labels=special_request.index, 
        autopct="%0.01f%%", explode=[0,1,0,0])

#Display the plot
plt.show()

# %%
#value counts for each counts
df['total_of_special_requests'].value_counts()

#checking unique value
df['total_of_special_requests'].unique()

# %%
#setting figure size
plt.figure(figsize=(10,8))

#plotting countplot for customer special requests 
sns.countplot(x=df['total_of_special_requests'], palette='muted')

#Setting the x-axis label
plt.xlabel('No of special request')

#Setting the y-axis label
plt.ylabel('Booking')

# Adding title
plt.title("Special Requests")

#Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason for picking this specific chart is to visualize the percentage of special requests made by different customer types.
#
#
# <br>The second chart is a countplot, which is useful for showing the distribution of categorical variables. It is used to display the frequency of different numbers of special requests made by customers.<br>

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart are as follows:
#
# The majority of special requests are made by Transient customers (83.0%).
#
# The Group customers have the lowest percentage of special requests (0.5%) compared to other customer types.
#
#
# From the first chart, we can see that most customers (almost 80%) do not make any special requests, while a small percentage (around 0.5%) make two or more special requests. From the second chart, we can see that the majority of customers (over 70%) make no special requests, while a small percentage (less than 5%) make three or more special requests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from these charts could help create a positive business impact if acted upon appropriately. For example, if the hotel sees that many customers are making multiple special requests, they could offer packages or incentives to encourage customers to make more requests, thereby increasing revenue. Alternatively, if the hotel sees that many customers are not making any special requests, they could offer more personalized services to entice customers to make requests and improve customer satisfaction.
#
# <br>There are no insights that lead to negative growth in these charts. However, if the hotel were to see that a large percentage of customers were making multiple special requests but were not satisfied with the service provided, it could lead to negative growth if the hotel did not address the issue promptly. Therefore, it is important to not only gather insights from data but also act on them appropriately to ensure positive business impact.<br>

# %% [markdown]
# #### Chart - 11 - What is the Highest and lowest number of booking over a year?

# %%
# Chart - 11 visualization code
# Group the bookings by hotel and month, then sum the number of bookings
monthly_bookings = df.groupby(["hotel", "arrival_date_month"]).size().reset_index(name="count")

# Set the size of the plot
plt.figure(figsize=(15, 8))

# Plot the data for each hotel
for hotel in monthly_bookings["hotel"].unique():
    data = monthly_bookings[monthly_bookings["hotel"] == hotel]

    #Ploting plot for highest and lowest booking month for both hotel
    if hotel == "Resort Hotel":
        plt.plot(data["arrival_date_month"], data["count"], marker="o", color="Black", label=hotel)
    else:
        plt.plot(data["arrival_date_month"], data["count"], marker="o", color="Red", label=hotel)
    
# Adding title
plt.title("Number of Bookings per Month and Hotel")

#Setting the x-axis label
plt.xlabel("Month")

#Setting the y-axis label
plt.ylabel("Number of Bookings")

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason for choosing a line chart is to visualize the trend of the number of bookings for each hotel over time (monthly). It is suitable for showing changes in data over a continuous period.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can see that both hotels experience similar patterns of bookings over the course of a year, with peak booking periods in the summer months and lower booking periods in the winter months. However, the Resort Hotel generally has a higher number of bookings than the City Hotel throughout the year. Additionally, there is a large drop in bookings for both hotels in the month of January.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart could help create a positive business impact if acted upon appropriately. For example, if the hotel sees that bookings are low during certain months, they could offer incentives or promotions to encourage more bookings during those periods. Alternatively, if the hotel sees that one hotel is consistently outperforming the other, they could investigate the reasons why and make changes to improve performance.
#
# <br>There are no insights that lead to negative growth in this chart. However, if the hotel were to see a sudden and significant drop in bookings over a longer period of time, it could lead to negative growth if the hotel did not address the issue promptly. Therefore, it is important to not only gather insights from data but also act on them appropriately to ensure positive business impact.<br>

# %% [markdown]
# #### Chart - 12 - Which Deposit Type Has Most No. of Booking Cancellation ?
#
#
#
# ###Customer request

# %%
# Filter the dataset to include only cancellations
deposit_cancel = df[df["is_canceled"]==1]

# Filter the dataset to include only cancellations
deposit_cancel = deposit_cancel["deposit_type"].value_counts().to_frame()

print(deposit_cancel)
# Out:
#             deposit_type
# No Deposit         29694
# Non Refund         14494
# Refundable            36

# %%
# Chart - 12 visualization code
# Setting figure size
plt.figure(figsize=(15,6))

# Create a horizontal bar plot using seaborn
sns.barplot(x=deposit_cancel["deposit_type"], y=deposit_cancel.index,data=deposit_cancel, palette="ocean", edgecolor="black")

# Set the title of the plot
plt.title("Deposit Type With Most No. of Cancellation")

# Set the x-axis label of the plot
plt.xlabel("Cancellation count")

# Set the y-axis label of the plot
plt.ylabel("Deposit Type")

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart is a horizontal bar plot, which is useful for comparing the values of different categories. In this case, it is used to compare the number of cancellations for different types of deposits.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can see that customers who did not make a deposit have the highest number of cancellations, followed by customers who made a non-refundable deposit. Customers who made a refundable deposit have the lowest number of cancellations. This suggests that customers who make a deposit are more likely to follow through with their booking, especially if the deposit is non-refundable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart could help create a positive business impact if acted upon appropriately. For example, if the hotel sees that customers who make a non-refundable deposit are less likely to cancel, they could consider offering more non-refundable deposit options to encourage customers to commit to their bookings.
#
# <br>There are no insights that lead to negative growth in this chart. However, if the hotel were to make all deposits non-refundable, it could potentially lead to negative growth if customers are hesitant to make a commitment and choose to book with a competitor instead. Therefore, it is important to balance the need for deposits with customer preferences and expectations to ensure positive business impact.<br>

# %% [markdown]
# #### Chart - 13 - Average Daily Rate On Weekend And Week night

# %%
# Chart - 13 visualization code

# Setting figure size
plt.figure(figsize=(15,6))

# Defining color palette
colors = ["green", "purple"]

# Creating lineplot
sns.lineplot(x=df["stays_in_week_nights"],y=df["adr"],marker="o",hue=df["hotel"],palette=colors)

# Setting title and displaying the plot
plt.title("Average Daily Rate On Week-Night")

#Display the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(15,6))

# Defining color palette
colors = ["green", "purple"]

#Plotting lineplot for weekend nughts
sns.lineplot(x=df["stays_in_weekend_nights"],y=df["adr"],marker="o",hue=df["hotel"],palette=colors)

# Adding title
plt.title("Average Daily Rate On Weekend-Night")

#Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason for choosing the specific chart is to analyze the relationship between the length of stay on week/weekend nights and the average daily rate (ADR) for hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the first chart, we can see that the ADR for city hotels remains relatively stable over the week, whereas for resort hotels, the ADR increases slightly from Monday to Thursday and then decreases over the weekend. In contrast, from the second chart, we can see that for both city and resort hotels, the ADR is higher on weekends than on weekdays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help hotels develop pricing strategies that can maximize their revenue. For example, hotels can consider increasing their rates during weekends, especially for resort hotels where the ADR tends to be higher on weekends. They can also consider offering lower rates during weekdays, especially for city hotels where the ADR remains relatively stable over the week. By doing so, hotels can optimize their revenue and occupancy rates by attracting customers who prefer to stay during certain days of the week.
#
# There are no insights that lead to negative growth from these charts.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

#setting figure size
plt.figure(figsize=(25,15))

#plotting correlation matrix for hotel booking dataframe
sns.heatmap(df.corr(),annot=True,cmap='PuOr')

# Adding title
plt.title('Co-relation of the columns')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart is a correlation heatmap, which is useful for identifying the relationships between different variables in a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can see that there are several strong positive and negative correlations between different variables in the hotel booking dataset.
#
#
# <br>Some possible insights that can be gained from the heatmap are:
#
# 1. There is a strong negative correlation between the 'is_canceled' and 'lead_time' columns, which suggests that bookings made farther in advance are less likely to be canceled.
# 2. There is a moderate positive correlation between the 'arrival_date_year' and 'adr' (average daily rate) columns, which indicates that hotel prices have increased over time.
# 3. There is a weak negative correlation between the 'stays_in_weekend_nights' and 'stays_in_week_nights' columns, which suggests that guests tend to stay longer on weekdays rather than weekends.
# 4. There is a moderate positive correlation between the 'total_of_special_requests' and 'adr' columns, which implies that guests who request special services tend to pay more for their stays.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# Remove missing values
df.dropna(inplace=True)

# Select the columns to include in the pair plot
columns = ["is_canceled", "lead_time", "arrival_date_year", "stays_in_weekend_nights", "stays_in_week_nights", "adults", "children", "babies", "required_car_parking_spaces", "total_of_special_requests"]

# Create the pair plot
sns.pairplot(df[columns])

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot is chosen to visualize the pairwise relationships between multiple variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights:
#
# The scatter plots show the relationships between two variables. For example, there seems to be a positive correlation between lead_time and is_canceled, indicating that bookings made farther in advance are more likely to be canceled.
#
#
# <br>The diagonal plots show the distribution of each variable. For example, the histograms show that the majority of bookings have no children and no babies, and that most bookings do not require a car parking space.<br>
#
#
# <br>The pair plot also shows that some variables are highly skewed and may require normalization before using them in a model.<br>

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the analysis of the hotel bookings dataset, there are several suggestions that could help the client achieve their business objective:
#
# 1. Increase marketing efforts in the months with low booking rates: As seen in the
# analysis, there are certain months where the hotel experiences low booking rates. By increasing marketing efforts during these months, the hotel can attract more guests and increase occupancy rates.
#
# 2. Improve customer satisfaction: Customer satisfaction is a key driver of loyalty and repeat business. By addressing customer complaints, improving the quality of service, and enhancing the overall guest experience, the hotel can attract more repeat customers and increase revenue.
#
# 3. Offer discounts and promotions during off-peak season: The hotel can offer discounts and promotions during months with low booking rates to incentivize guests to book during these times. This can help increase occupancy rates and revenue during traditionally slow periods.
#
# 4. Optimize pricing strategy: The hotel can optimize their pricing strategy by analyzing demand patterns and adjusting rates accordingly. By pricing rooms based on demand, the hotel can maximize revenue during peak periods and attract more guests during off-peak periods.
#
# 5. Implement revenue management practices: Revenue management practices can help the hotel optimize pricing and distribution strategies to maximize revenue. This can include dynamic pricing, inventory management, and channel management.
#
# 6. Enhance online booking process: In the digital age, most guests book their hotel rooms online. By enhancing the online booking process, the hotel can improve the guest experience, reduce booking errors, and increase direct bookings, which can lead to higher profitability.
#
# Overall, the client should focus on strategies that enhance the guest experience, optimize pricing and distribution, and increase occupancy rates during traditionally slow periods. By implementing these strategies, the hotel can achieve its business objective of maximizing revenue and profitability.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. Almost 66% of the total guests opt for a city hotel instead of a resort hotel.
#
# 2. According to the analysis, both hotels are being affected by a high rate of cancellations. The fact that a large portion of these reservations did not have a deposit indicates that customers are more inclined to cancel a reservation when they are not required to put down a deposit. The company should change the cancellation policy to make it a bit more restrictive. Additionally, it should conduct a brief survey of customers when they cancel a reservation to find out why they do so.
#
# 3. On the other hand, there is a very low number of repeated clients, so a loyalty strategy could be created, especially for clients coming from Portugal, as they are the main clients for both hotels. In addition, their proximity to both hotels would increase the likelihood of repeat stays.
#
#
# 4. It would also be advisable to conduct a satisfaction survey with clients who confirm their stay in order to find out their general impressions of the services offered. For example, according to the data, the bed and breakfast regime is the most requested, so it would be important to verify that its quality meets the expectations of the clients.
#
#
#
# 5. Finally, the low occupancy of rooms by adults with children seems to indicate that none of the hotels has a family-friendly atmosphere. Consequently, it would be worth considering what services could be included to attract this type of client or whether, on the contrary, efforts should be focused on attracting couples and groups of adults to the hotel, offering more exclusive services.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %% [markdown]
# ## Refrence
#
#
#
# 1.   Almabetter
# 2.   Kaggle
# 3.   Github
# 4.   ScienceDirect
